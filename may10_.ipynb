# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/may10_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
comprehensions 2 to 3 line converted in 1 line lenda function single line converted insingle line.
# Out:
#   File "<ipython-input-4-66442a9a07d6>", line 1
#     comprehensions 2 to 3 line converted in 1 line lenda function single line converted insingle line.
#                    ^
# SyntaxError: invalid syntax

# %%
list = [i for i in range(1,10)]

# %%
is_even = [i for i in range(1,10) if i%2==0]

# %%
is_even = True if i % 2==0 else False
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-2dad636646d2> in <cell line: 0>()
# ----> 1 is_even = True if i % 2==0 else False
#
# NameError: name 'i' is not defined

# %%
def square():
 list =[i for i in range(1,10)]
 return list

# %%
square()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
x = square()

# %% [markdown]
# Give input no output

# %%
def name():
 print("hello")

# %%
name()
# Out:
# hello

# %%
print(name())
# Out:
# hello
# None

# %%
def name(name):
 print("zahabia")

# %%
def name(name):
  print(zahabia)

# %%
def name(user_name):
 print("hello", user_name)

# %%
global_name(name)

# %%
global_name = "zahabia"
def name():
  print(global_name)

# %%
def name(user_name("zahabia")):
 print("hello", user_name)

# %%
def addition(a=3+b=2):
return(addition)

# %%
addition()

# %%
addition(6+7)

# %%
def addition(a=6,b=7):
  print(a=6)
  print(b=7)
  return(addition)

# %%
def check(input("enter a number"))
if num is even print("even")
else print("False")
