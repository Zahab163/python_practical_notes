# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/tasks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#initiate an empty dictionary to store events
events = {}
#function to add an event
def add_event(event_name, date, time,location ):
  if event_name not in events:
    events[event_name] = {
        "date": date,
        "time": time,
        "location": location,
        "guest_no" : guest
    }
    print(f"Event'[event_name]'added successfully!")
  else:
    print(f"Event'[event_name]'already exists.")

# %%
#function to view event details
def view_event(event_name):
  if event_name in events:
    event_details = events[event_name]
    print(f"Event: {event_name}")
    print(f"Date: {event_details['date']}")
    print(f"Time: {event_details['time']}")
    print(f"Location: {event_details['location']}")
    print(f"Guest_No: {event_details['guest_no']}")
  else:
    print(f"Event'[event_name]'does not exist.")

# %%
#function to list all events
def list_events():
  if events:
    print("List of Events: ")
    for event_name in events:
      print(f"-{event_name}")
  else:
    print("No events found.")

# %%
def add_evnt(event_name, date, time, location ):
  add_event("Seminar" ,"11-03-2025", "09:00", "SMIT","300")
  add_event("Team Meeting", "20-04-2025", "10:00", "100")
  list_events()
  view_event("Seminar")
  view_event("Wedding") # Example of viewing a non-existent event
