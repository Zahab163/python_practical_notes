# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/Expense_TrackerProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Source code ( python)
# File Name : expense tracker project.
# This is a financial health summary for Zahabia Ahmed According to Sarah's financial statement.
#
#
#
# **bold text**

# %%
print ("====expense tracker====")
# Out:
# ====expense tracker====

# %%
name = input("Enter your name:")
# Out:
# Enter your name: Zahabia Ahmed

# %%
profession = input ("Enter your Profession:")
# Out:
# Enter your Profession: Entrepreneur

# %%
print ("Welcome",name.title(),"! Let's analyze your financial health as a" ,profession.title()  )
# Out:
# Welcome  Zahabia Ahmed ! Let's analyze your financial health as a  Entrepreneur

# %%
# Taking income and expenses as input and showing them and savins it in %format with a message
income =int (input("Enter your income:"))
expenses =int (input("Enter your expenses:"))
savings = income - expenses
savings_percentage = (savings / income)*100
# Out:
# Enter your income: 80000
# Enter your expenses: 60000

# %%
# Taking income and expenses as input and showing them and savings it in %format with a message
income = int(input("Enter your income:"))
expenses = int(input("Enter your expenses:"))
# Out:
# Enter your income: 80000
# Enter your expenses:60000

# %%
print(savings)  # Display savings if needed
print(savings_percentage)
if (expense>income):
  print( "Sorry! you entered expenses more then income.")
else:
    print("Total savings:",savings)
    print("savings percentage:",savings_percentage,"%")
print(savings)  # Display savings if needed
print(savings_percentage)
if (expense>income):
  print( "Sorry! you entered expenses more then income.")
else:
    print("Totangs_percentage>=10):
          print("Good!",name.title(), "but you could try to save some more." )
      else:
            print("Warning!",name.title(),"your savings are too low. consider cutting your expenses.")
            print("")
        l savings:",savings)
    print("savings percentage:",savings_percentage,"%")
    if (savings_percentage>=20):
      print("Great Job!", name.title()," ! you have a strong saving habit.")
     else :
     if (savi
# Out:
#   File "<tokenize>", line 15
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
print(savings)  # Display savings if needed
print(savings_percentage)
if (expense>income):
  print( "Sorry! you entered expenses more then income.")
  else:
    print("Total savings:",savings)
    print("savings percentage:",savings_percentage,"%")
    if (savings_percentage>=20):
      print("Great Job!", name.title()," ! you have a strong saving habit.")
      else :
        if (savings_percentage>=10):
          print("Good!"name.title(), "but you could try to save some more." )
          else:
            print("Warning!",name.title(),"your savings are too low. consider cutting your expenses.")
            print("")
# Out:
#   File "<tokenize>", line 5
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level
