# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/List_%7C_Class%7C_Decorators.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
table = int(input("enter a number in which you want:"))
for value in range(1,16):
  print (f"{table}*{value}={table*value}")
# Out:
# enter a number in which you want:5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
# 5*11=55
# 5*12=60
# 5*13=65
# 5*14=70
# 5*15=75

# %%
num=int (input("enter a number"))
# Out:
# enter a number6

# %%
for i in range (1,num+1):
  for j in range (1,11):
    print(f"{i} * {j} = ",i* j ) #Corrected the indentation and the f-string formatting
# Out:
# 1 * 1 =  1
# 1 * 2 =  2
# 1 * 3 =  3
# 1 * 4 =  4
# 1 * 5 =  5
# 1 * 6 =  6
# 1 * 7 =  7
# 1 * 8 =  8
# 1 * 9 =  9
# 1 * 10 =  10
# 2 * 1 =  2
# 2 * 2 =  4
# 2 * 3 =  6
# 2 * 4 =  8
# 2 * 5 =  10
# 2 * 6 =  12
# 2 * 7 =  14
# 2 * 8 =  16
# 2 * 9 =  18
# 2 * 10 =  20
# 3 * 1 =  3
# 3 * 2 =  6
# 3 * 3 =  9
# 3 * 4 =  12
# 3 * 5 =  15
# 3 * 6 =  18
# 3 * 7 =  21
# 3 * 8 =  24
# 3 * 9 =  27
# 3 * 10 =  30
# 4 * 1 =  4
# 4 * 2 =  8
# 4 * 3 =  12
# 4 * 4 =  16
# 4 * 5 =  20
# 4 * 6 =  24
# 4 * 7 =  28
# 4 * 8 =  32
# 4 * 9 =  36
# 4 * 10 =  40
# 5 * 1 =  5
# 5 * 2 =  10
# 5 * 3 =  15
# 5 * 4 =  20
# 5 * 5 =  25
# 5 * 6 =  30
# 5 * 7 =  35
# 5 * 8 =  40
# 5 * 9 =  45
# 5 * 10 =  50
# 6 * 1 =  6
# 6 * 2 =  12
# 6 * 3 =  18
# 6 * 4 =  24
# 6 * 5 =  30
# 6 * 6 =  36
# 6 * 7 =  42
# 6 * 8 =  48
# 6 * 9 =  54
# 6 * 10 =  60

# %%
names_list =["sonia" ,"manahil" , "ayesha" ,"fozia"]

# %%
print(names_list)
# Out:
# ['sonia', 'manahil', 'ayesha', 'fozia']

# %%
list (range(1,11))

# %%
age =[]

# %%
age =list (age)

# %%
age.append(12)
print (age)
# Out:
# [12, 12, 12, 12, 12]

# %%
animals_list =[]
animal = input("enter a animal")
animals.append(animal)

# %%
animal=input("enter a animal")
# Out:
# enter a animaldog

# %%
list_1 = ("Samar", "20" ,"Inter")
list_2 = ("Zahabia" , "30" ,"B.sc")
list_3 =("Afsheen", "35" ,"M.ba")

# %%
lists =[list_1,list_]

# %%
candidates=[]

# %%
particular_student= []

# %%
name =input("enter your name ")
age =int(input("enter your age"))
education = input("enter your education")

# %%
particular_student.append(["name", "age","education"])

# %%
attributes are variables ...classes ko object oreinted ,multiple things in class are called objects list .append Function , is based on classs ...format is a fun string...

# %%
class ka keyword attributes Variable s , constructured functionssave attributes--init

# %%
class Employement:
  def __init__(self) -> None:
    pass

# %%
class Student:
  def  __init__(self, name , education):
    self.name = "Aqsa"
    self.age = 23
    self.education = education

  def greeting(self):
    print("Hello" , self.name)

# %%
student_1 = Student("Aqsa", "Matric")

# %%
student_1.greeting()
# Out:
# Hello Aqsa

# %%
student_2 = Student("Ali", "Matric")

# %%
student_2.greeting()
# Out:
# Hello Aqsa

# %%
class Student:
  def  __init__(self, name , education):
    self.name = "Aqsa"
    self.age = 23
    self.education = education

  def greeting(abc):
    print("Hello" , abc.name)

# %%
class Student:
  def  __init__(self, name , age,  education):
    self.name = name
    self.age = age
    self.education = education

  def greeting(self):
    print("Hello" , self.name,self.age ,self.education)

# %%
student_3 = Student("salman",26 ,"B.com")

# %%
student_3.greeting()
# Out:
# Hello salman 26 B.com

# %%
name = input("enter your name ")
age = int(input("enter your age "))
education = input("enter your education ")
# Out:
# enter your name Arsalan
# enter your age 19
# enter your education B.com

# %%
student_4 =Student( name , age , education)

# %%
student_4.greeting()
# Out:
# Hello Arsalan 19 B.com

# %% [markdown]
# dependent ,and independent function (methods) one type of method is what class is defined or not :
# Static Method without class like self
# 2.
# decorators : class method , dependant ,indepently

# %%
class Student:
  def  __init__(self, name , age,  education):
    self.name = name
    self.age = age
    self.education = education

  def greeting(self):
    print("Hello" , self.name,self.age ,self.education)

# %%
class Math:
  @staticmethod
  def add(a,b):
    return a+b

# %%
print(Math.add(80,9))
# Out:
# 89

# %%
class Student:
  @staticmethod
    def greeting(name ,age , education):
    print("Hello" , name,age ,education)
# Out:
#   File "<ipython-input-57-a021ffc0e143>", line 3
#     def greeting(name ,age , education):
#     ^
# IndentationError: unexpected indent

# %%
class Student:
  @staticmethod
  def greeting(name ,age , education):
    print("Hello" , name,age ,education)

# %%
student_5 =Student()

# %%
student_5.greeting("Aqsa",23,"Matric")
# Out:
# Hello Aqsa 23 Matric

# %% [markdown]
# a logical entity with specific attributes and methods. For example, if the class is a pen, it will have attributes and methods like color, type, etc. OOPs in Python primarily deals with classes and objects. Classes define functions, known as methods, that describe the actions and behaviors an object can perform.types of opps :(object oriented programming)
# inheritence Inheritance in Object-Oriented Programming (OOP) allows a class (the derived or child class) to inherit properties and methods from another class (the base or parent class). ,
#  pollymorphism:the same function name is being used for different types. Each function is differentiated based on its data type and number of arguments. So, each function has a different signature. This allows developers to write clean, readable, and resilient codes.,
#  incapsulation:In Object-Oriented Programming (OOP), encapsulation is the bundling of data (attributes) and the methods (functions) that operate on that data into a single unit, typically a class,
#  abstraction:In Object-Oriented Programming (OOP), abstraction is the process of hiding complex implementation details and showing only the essential information to the user.
# difference between inheritence and abstraction

# %%
def greeting("Sarim",20,"Inter"):
    @staticmethod
    print("Hello" , name,age ,education)
# Out:
#   File "<ipython-input-66-70796bb5c824>", line 1
#     def greeting("Sarim",20,"Inter"):
#                  ^
# SyntaxError: invalid syntax

# %%
calss Human:
def __init__(self ,region):
  self.region =region

  def introduction(abc):
    print("This Human comes from", abc.region)

class Asia(human):
  def __init__(self ,region ,culture):
    #super( )__init__(region)
    self.culture = culture
    self.life_style = life_style

  def life_style(abc)
  print(F"the {abc.life_style} life_styleis in the {abc.region}")

# %% [markdown]
# c
