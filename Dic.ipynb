# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/Dic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list_of_skills =["python","dm","va","c++","msword","logistics"]

# %%
employee_data = {
    "employe_id": 234,
    "employe_name": "Zahabia",
    "experience": "two_years",
    "employee_salary": 100000000,
    "employ_designation": "GM",
    "employee_skills": list_of_skills,
    "experience_details ": {"company_id":1,
    "designation" :"manager",
    "salary": 100000,
    "skills" :["c++", "python"]}
}
    "skills" :["c++", "python"]}
}
# Out:
#   File "<ipython-input-3-92a9ace33b31>", line 13
#     "skills" :["c++", "python"]}
#     ^
# IndentationError: unexpected indent

# %%
employee_data = {
    "employe_id": 1,
    "employe_name": "Zahabia",
    "experience": "two_years",
    "employee_salary": 100000000,
    "employ_designation": "GM",
    "employee_skills": list_of_skills,
    "experience_details": [
        {"company_id": 1,
         "designation": "manager",
         "salary": 100000,
         "skills": ["c++", "python"]},
        {"company_id": 2,
         "designation": "Assisstant_Manager",
         "salary": 10000,
         "skills": ["c++,python, dm,logistics,data engineering"]}
    ]
}

# %%
 {
    "employe_id": 2,
    "employe_name": "salman",
    "experience": "two_years",
    "employee_salary": 100000000,
    "employ_designation": "GM",
    "employee_skills": list_of_skills,
    "experience_details": [
        {"company_id": 1,
         "designation": "manager",
         "salary": 100000,
         "skills": ["c++", "python"]},
        {"company_id": 2,
         "designation": "Assisstant_Manager",
         "salary": 10000,
         "skills": ["c++,python, dm,logistics"]}
    ]
}
# Out:
# {'employe_id': 2,
#  'employe_name': 'salman',
#  'experience': 'two_years',
#  'employee_salary': 100000000,
#  'employ_designation': 'GM',
#  'employee_skills': ['python', 'dm', 'va', 'c++', 'msword', 'logistics'],
#  'experience_details': [{'company_id': 1,
#    'designation': 'manager',
#    'salary': 100000,
#    'skills': ['c++', 'python']},
#   {'company_id': 2,
#    'designation': 'Assisstant_Manager',
#    'salary': 10000,
#    'skills': ['c++,python, dm,logistics']}]}

# %%
for range in employee_data:
    print(range)
# Out:
# employe_id
# employe_name
# experience
# employee_salary
# employ_designation
# employee_skills
# experience_details

# %%
for range in employee_data["employee_skills"]:
    print(range)
# Out:
# python
# dm
# va
# c++
# msword
# logistics

# %%
for key in employee_data:
    print(key)
# Out:
# employe_id
# employe_name
# experience
# employee_salary
# employ_designation
# employee_skills
# experience_details

# %%
for skills in employee_data["employee_skills"]:
    print(skills)
# Out:
# python
# dm
# va
# c++
# msword
# logistics

# %%
for main_skill in employee_data["employee_skills"]:
    print(main_skill)
# Out:
# python
# dm
# va
# c++
# msword
# logistics

# %%
for experience in employee_data["experience_details"]:
    print(experience)
# Out:
# {'company_id': 1, 'designation': 'manager', 'salary': 100000, 'skills': ['c++', 'python']}
# {'company_id': 2, 'designation': 'Assisstant_Manager', 'salary': 10000, 'skills': ['c++,python, dm,logistics,data engineering']}

# %%
experience_skills_str = experience["skills"][0]

# %%
experience_skills_list = [skill.strip() for skill in experience_skills_str.split(',')]
if main_skill in experience_skills_list:
            print(f"  Matched with experience skills: {experience_skills_str}")
# Out:
#   Matched with experience skills: c++,python, dm,logistics,data engineering

# %%
for main_skill in employee_data["employee_skills"]:
    print(f"Checking skill: {main_skill}")
    found_match = False
    for experience in employee_data
    xperience_skills-str = experience["skills"][0]
    experience_skills_list = [skill.strip() for skill in experience_skills_str.split(',')]
    if main_skill in experience_skills_list:
 print(f"  Matched with experience skills: {experience_skills_str}")
 found_match =True
# Out:
#   File "<tokenize>", line 8
#     print(f"  Matched with experience skills: {experience_skills_str}")
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
for main_skill in employee_data["employee_skills"]:
    print(f"Checking skill: {main_skill}")
    found_match = False
    for experience in employee_data["experience_details"]:
        experience_skills_str = ", ".join(experience.get("skills", [])) # Handle missing 'skills' key
        experience_skills_list = [skill.strip() for skill in experience_skills_str.split(',') if skill.strip()] # Handle empty strings

        if main_skill in experience_skills_list:
            print(f"  Matched with experience skills: {experience_skills_str}")
            found_match = True

            # break
    if not found_match:
        print(f"  No match found in experience details for {main_skill}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e5f44106debd> in <cell line: 0>()
# ----> 1 for main_skill in employee_data["employee_skills"]:
#       2     print(f"Checking skill: {main_skill}")
#       3     found_match = False
#       4     for experience in employee_data["experience_details"]:
#       5         experience_skills_str = ", ".join(experience.get("skills", [])) # Handle missing 'skills' key
#
# NameError: name 'employee_data' is not defined

# %%
employee_1= {"employee_id":1,
            "employee_name":"Sony",
            "employee_salary":100000000,
            "employee_designation":"CEO",
            "employee_skills":["python","AI_engineer", "data_scientist","Management","Digital_Marketing"],
            "employee_experience":[
                {"company_Id":1,
                 "designation": "assistant",
                 "salary":100000,
                 "skills":"python, Javascript " },
                {"company_id":2,
                 "designation": "assistant_manager",
                 "salary" :1000000,
                 "skills":"python, AI_engineer, web_development"}

           ]
           }

# %%
employee_2 = {"employee_id": 2,
           "employee_name": "Shiza",
           "employee_salary": 100000000,
           "employee_designation": "Manager",
           "employee_skills": ["python", "AI_engineer", "data_scientist", "supervision" ] ,
           "employee_experience": [
               {"company_Id": 1,
                "designation": "assistant",
                "salary": 100000,
                "skills": "python, Javascript "},
               {"company_id": 2,
                "designation": "assistant_manager",
                "salary": 1000000,
                "skills": ["python, AI_engineer, web_development"]}

           ]
           }

# %%
Employee_list =[employee_1,employee_2]

# %%
print(Employee_list)
# Out:
# [{'employee_id': 1, 'employee_name': 'Sony', 'employee_salary': 100000000, 'employee_designation': 'CEO', 'employee_skills': ['python', 'AI_engineer', 'data_scientist', 'Management', 'Digital_Marketing'], 'employee_experience': [{'company_Id': 1, 'designation': 'assistant', 'salary': 100000, 'skills': 'python, Javascript '}, {'company_id': 2, 'designation': 'assistant_manager', 'salary': 1000000, 'skills': 'python, AI_engineer, web_development'}]}, {'employee_id': 2, 'employee_name': 'Shiza', 'employee_salary': 100000000, 'employee_designation': 'Manager', 'employee_skills': ['python', 'AI_engineer', 'data_scientist', 'supervision'], 'employee_experience': [{'company_Id': 1, 'designation': 'assistant', 'salary': 100000, 'skills': 'python, Javascript '}, {'company_id': 2, 'designation': 'assistant_manager', 'salary': 1000000, 'skills': ['python, AI_engineer, web_development']}]}]

# %%
print(employee_1)(skills)
# Out:
# {'employee_id': 1, 'employee_name': 'Sony', 'employee_salary': 100000000, 'employee_designation': 'CEO', 'employee_skills': ['python', 'AI_engineer', 'data_scientist', 'Management', 'Digital_Marketing'], 'employee_experience': [{'company_Id': 1, 'designation': 'assistant', 'salary': 100000, 'skills': 'python, Javascript '}, {'company_id': 2, 'designation': 'assistant_manager', 'salary': 1000000, 'skills': 'python, AI_engineer, web_development'}]}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-69d3cacf9b8e> in <cell line: 0>()
# ----> 1 print(employee_1)(skills)
#
# NameError: name 'skills' is not defined

# %%
# Access the employee_experience list
employee_experience = employee_1["employee_experience"]

# Iterate through each experience entry
for experience in employee_experience:
    # Access the skills for the current experience
    skills_data = experience.get("skills") # Use .get() to handle potential missing key
    if skills_data:
        # If skills is a string, split it and print
        if isinstance(skills_data, str):
            skills_list = [skill.strip() for skill in skills_data.split(',') if skill.strip()]
            print(f"Experience Skills: {', '.join(skills_list)}")
        # If skills is already a list, print its elements
        elif isinstance(skills_data, list):
            print(f"Experience Skills: {', '.join(skills_data)}")
# Out:
# Experience Skills: python, Javascript
# Experience Skills: python, AI_engineer, web_development

# %%
# You can install Faker if you want more realistic data:
# !pip install Faker

from faker import Faker
import random

# Initialize Faker
fake = Faker()

def create_employee(employee_id):
    """Creates a dictionary representing a single employee."""
    return {
        "employee_id": employee_id,
        "employee_name": fake.name(),
        "employee_salary": random.randint(50000, 200000),  # Simulate salary range
        "employee_designation": random.choice(["Manager", "Developer", "Analyst", "Designer"]), # Simulate designation
        "employee_skills": random.sample(["python", "java", "SQL", "machine learning", "data analysis", "communication"], k=random.randint(1, 5)), # Simulate skills
        "employee_experience": [
            {"company_id": fake.random_int(min=1, max=10),
             "designation": fake.job(),
             "salary": random.randint(30000, 150000),
             "skills": ", ".join(random.sample(["python", "java", "SQL", "machine learning", "data analysis", "communication"], k=random.randint(1, 3)))}
        ]
    }

# Create a list of 100 employees
employee_list = [create_employee(i) for i in range(1, 1001)]

# To see the generated list:
# print(employee_list)

# %%
employee_list = []
print(employee_list)
# Out:
# []

# %%
employee_list = [create_employee(i) for i in range(1, 1001)]
print(employee_list)
# Out:
# [{'employee_id': 1, 'employee_name': 'George Hamilton', 'employee_salary': 104667, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'java'], 'employee_experience': [{'company_id': 8, 'designation': 'Science writer', 'salary': 105497, 'skills': 'data analysis'}]}, {'employee_id': 2, 'employee_name': 'Theresa Johnson', 'employee_salary': 152056, 'employee_designation': 'Developer', 'employee_skills': ['python', 'java', 'data analysis'], 'employee_experience': [{'company_id': 2, 'designation': 'Holiday representative', 'salary': 40395, 'skills': 'communication'}]}, {'employee_id': 3, 'employee_name': 'Jacqueline Harris', 'employee_salary': 167181, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Optometrist', 'salary': 128339, 'skills': 'java, data analysis, machine learning'}]}, {'employee_id': 4, 'employee_name': 'Nathaniel Henry', 'employee_salary': 1
# ...

# %%
(employee_list)
# Out:
# [{'employee_id': 1, 'employee_name': 'George Hamilton', 'employee_salary': 104667, 'employee_designation': 'Analyst', 'employee_skills': ['data analysis', 'java'], 'employee_experience': [{'company_id': 8, 'designation': 'Science writer', 'salary': 105497, 'skills': 'data analysis'}]}, {'employee_id': 2, 'employee_name': 'Theresa Johnson', 'employee_salary': 152056, 'employee_designation': 'Developer', 'employee_skills': ['python', 'java', 'data analysis'], 'employee_experience': [{'company_id': 2, 'designation': 'Holiday representative', 'salary': 40395, 'skills': 'communication'}]}, {'employee_id': 3, 'employee_name': 'Jacqueline Harris', 'employee_salary': 167181, 'employee_designation': 'Analyst', 'employee_skills': ['machine learning', 'python', 'data analysis'], 'employee_experience': [{'company_id': 1, 'designation': 'Optometrist', 'salary': 128339, 'skills': 'java, data analysis, machine learning'}]}, {'employee_id': 4, 'employee_name': 'Nathaniel Henry', 'employee_salary': 1
# ...
