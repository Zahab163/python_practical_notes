# %% [markdown]
# <a href="https://colab.research.google.com/github/Zahab163/python_practical_notes/blob/main/BillCal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q; Write a program to calculate bill (accept number of unit from user ) according to the following criteria:
#
#
# 1.    for 100 units= 0
# 2.    for 200 units = rs. 5/unit
# 3.   for +200 uints= rs. 10/ unit

# %%
def calculate_bill(units):
  if units <=100:
    rate =0
  elif units <=200:
   rate =5
  elif units >=200:
   rate =10
  amount =units *rate
  return amount

# %%
def calculate_bill(units):
  if units <=100:
    rate =0
  elif units <=200:
   rate =5
  elif units >=200:
   rate =10
  amount =units *rate
  return amount
  units_consumed =int (input("enter the no. of units consumed: "))
  bill_amount =calculate_bill(units_consumed)
  Print ("bill amount: ", bill_amount )

# %%
unit_consumed = int(input("Enter the no. of units consumed: "))
bill_amount = calculate_bill(unit_consumed)
print("Bill Amount:", bill_amount)
print("Bill Amount:", bill_amount)
# Out:
# Enter the no. of units consumed: 350
# Bill Amount: 3500
# Bill Amount: 3500
